# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # to use operating system dependent functionality
import librosa # to extract speech features
import wave # read and write WAV files
import matplotlib.pyplot as plt # to generate the visualizations

# MLP Classifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# LSTM Classifier
import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import *
from keras.optimizer_v1 import rmsprop

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def extract_mfcc(wav_file_name):
    #This function extracts mfcc features and obtain the mean of each dimension
    #Input : path_to_wav_file
    #Output: mfcc_features'''
    y, sr = librosa.load(wav_file_name)
    mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T,axis=0)
    
    return mfccs

# %%
##### load radvess speech data #####
radvess_speech_labels = [] # to save extracted label/file
ravdess_speech_data = [] # to save extracted features/file
for dirname, _, filenames in os.walk('/content/drive/MyDrive/Colab Notebooks/ravdess-emotional-speech-audio/'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        radvess_speech_labels.append(int(filename[7:8]) - 1) # the index 7 and 8 of the file name represent the emotion label
        wav_file_name = os.path.join(dirname, filename)
        ravdess_speech_data.append(extract_mfcc(wav_file_name)) # extract MFCC features/file
        
print("Finish Loading the Dataset")
# Out:
# Finish Loading the Dataset

# %%
#### convert data and label to array
ravdess_speech_data_array = np.asarray(ravdess_speech_data) # convert the input to an array
ravdess_speech_label_array = np.array(radvess_speech_labels)
ravdess_speech_label_array.shape # get tuple of array dimensions

#### make categorical labels
labels_categorical = to_categorical(ravdess_speech_label_array) # converts a class vector (integers) to binary class matrix
labels_categorical.shape
# Out:
# (2880, 8)

# %%
ravdess_speech_data_array.shape
# Out:
# (2880, 40)

# %%
x_train,x_test,y_train,y_test= train_test_split(np.array(ravdess_speech_data_array),labels_categorical, test_size=0.20, random_state=9)

# %%
# Split the training, validating, and testing sets
number_of_samples = ravdess_speech_data_array.shape[0]
training_samples = int(number_of_samples * 0.8)
validation_samples = int(number_of_samples * 0.1)
test_samples = int(number_of_samples * 0.1)

# %%
# Define the LSTM model
def create_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(40, 1)))
    model.add(Dense(64))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(8))
    model.add(Activation('softmax'))
    
    # Configures the model for training
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
w = np.expand_dims(ravdess_speech_data_array[:training_samples],-1)

# %%
w.shape
# Out:
# (2304, 40, 1)

# %%
### train using LSTM model
model_A = create_model_LSTM()
history = model_A.fit(np.expand_dims(ravdess_speech_data_array[:training_samples],-1), labels_categorical[:training_samples], validation_data=(np.expand_dims(ravdess_speech_data_array[training_samples:training_samples+validation_samples], -1), labels_categorical[training_samples:training_samples+validation_samples]), epochs=121, shuffle=True)
# Out:
# Epoch 1/121
# 72/72 [==============================] - 22s 16ms/step - loss: 2.0729 - accuracy: 0.1572 - val_loss: 2.0343 - val_accuracy: 0.2188
# Epoch 2/121
# 72/72 [==============================] - 0s 6ms/step - loss: 2.0383 - accuracy: 0.1805 - val_loss: 1.9747 - val_accuracy: 0.2743
# Epoch 3/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.9831 - accuracy: 0.2369 - val_loss: 1.9378 - val_accuracy: 0.2500
# Epoch 4/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.9383 - accuracy: 0.2566 - val_loss: 1.9181 - val_accuracy: 0.2812
# Epoch 5/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.9344 - accuracy: 0.2466 - val_loss: 1.8763 - val_accuracy: 0.2361
# Epoch 6/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.9038 - accuracy: 0.2543 - val_loss: 1.7957 - val_accuracy: 0.3403
# Epoch 7/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.8508 - accuracy: 0.2904 - val_loss: 1.9439 - val_accuracy: 0.2257
# Epoch 8/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.8528 - accuracy: 0.2761 - val_loss: 1.8166 - val_accuracy: 0.2917
# Epoch 9/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.8579 - accuracy: 0.2751 - val_loss: 1.8403 - val_accuracy: 0.2986
# Epoch 10/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.8090 - accuracy: 0.2973 - val_loss: 1.8149 - val_accuracy: 0.2986
# Epoch 11/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.7571 - accuracy: 0.3140 - val_loss: 1.7592 - val_accuracy: 0.2951
# Epoch 12/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.7537 - accuracy: 0.3061 - val_loss: 1.8614 - val_accuracy: 0.2708
# Epoch 13/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.7415 - accuracy: 0.3360 - val_loss: 1.7492 - val_accuracy: 0.3160
# Epoch 14/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.7401 - accuracy: 0.3204 - val_loss: 1.7355 - val_accuracy: 0.3507
# Epoch 15/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.7075 - accuracy: 0.3661 - val_loss: 1.7096 - val_accuracy: 0.3194
# Epoch 16/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.6969 - accuracy: 0.3613 - val_loss: 1.7066 - val_accuracy: 0.3472
# Epoch 17/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.6720 - accuracy: 0.3581 - val_loss: 1.6612 - val_accuracy: 0.3785
# Epoch 18/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.6439 - accuracy: 0.4007 - val_loss: 1.6661 - val_accuracy: 0.3611
# Epoch 19/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.6417 - accuracy: 0.3800 - val_loss: 1.6034 - val_accuracy: 0.3993
# Epoch 20/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.5946 - accuracy: 0.3878 - val_loss: 1.5864 - val_accuracy: 0.4375
# Epoch 21/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.5952 - accuracy: 0.4116 - val_loss: 1.5291 - val_accuracy: 0.4375
# Epoch 22/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.5936 - accuracy: 0.4183 - val_loss: 1.6099 - val_accuracy: 0.4236
# Epoch 23/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4904 - accuracy: 0.4419 - val_loss: 1.5968 - val_accuracy: 0.3889
# Epoch 24/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4793 - accuracy: 0.4407 - val_loss: 1.5967 - val_accuracy: 0.4444
# Epoch 25/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.4963 - accuracy: 0.4475 - val_loss: 1.5437 - val_accuracy: 0.4410
# Epoch 26/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4948 - accuracy: 0.4480 - val_loss: 1.5391 - val_accuracy: 0.4410
# Epoch 27/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4930 - accuracy: 0.4545 - val_loss: 1.4818 - val_accuracy: 0.4444
# Epoch 28/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4425 - accuracy: 0.4547 - val_loss: 1.4835 - val_accuracy: 0.4618
# Epoch 29/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.4234 - accuracy: 0.4623 - val_loss: 1.4010 - val_accuracy: 0.4688
# Epoch 30/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.4195 - accuracy: 0.4726 - val_loss: 1.3911 - val_accuracy: 0.4861
# Epoch 31/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.4365 - accuracy: 0.4649 - val_loss: 1.5126 - val_accuracy: 0.4236
# Epoch 32/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4012 - accuracy: 0.4684 - val_loss: 1.4150 - val_accuracy: 0.4583
# Epoch 33/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.4120 - accuracy: 0.4878 - val_loss: 1.3480 - val_accuracy: 0.5139
# Epoch 34/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.3329 - accuracy: 0.5061 - val_loss: 1.3590 - val_accuracy: 0.4931
# Epoch 35/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.2820 - accuracy: 0.4997 - val_loss: 1.3379 - val_accuracy: 0.5000
# Epoch 36/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.3345 - accuracy: 0.4893 - val_loss: 1.2743 - val_accuracy: 0.5208
# Epoch 37/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.2718 - accuracy: 0.5236 - val_loss: 1.2979 - val_accuracy: 0.5312
# Epoch 38/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.3018 - accuracy: 0.5217 - val_loss: 1.3414 - val_accuracy: 0.4861
# Epoch 39/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.2428 - accuracy: 0.5322 - val_loss: 1.3231 - val_accuracy: 0.5104
# Epoch 40/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.2468 - accuracy: 0.5136 - val_loss: 1.3152 - val_accuracy: 0.4826
# Epoch 41/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1980 - accuracy: 0.5540 - val_loss: 1.2045 - val_accuracy: 0.5278
# Epoch 42/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1677 - accuracy: 0.5542 - val_loss: 1.2125 - val_accuracy: 0.5590
# Epoch 43/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1576 - accuracy: 0.5570 - val_loss: 1.1691 - val_accuracy: 0.5312
# Epoch 44/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1593 - accuracy: 0.5627 - val_loss: 1.1379 - val_accuracy: 0.5660
# Epoch 45/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.0937 - accuracy: 0.5866 - val_loss: 1.1141 - val_accuracy: 0.5833
# Epoch 46/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.0668 - accuracy: 0.5984 - val_loss: 1.0684 - val_accuracy: 0.6007
# Epoch 47/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1174 - accuracy: 0.5799 - val_loss: 1.0854 - val_accuracy: 0.5903
# Epoch 48/121
# 72/72 [==============================] - 0s 5ms/step - loss: 1.1053 - accuracy: 0.5762 - val_loss: 1.0422 - val_accuracy: 0.6111
# Epoch 49/121
# 72/72 [==============================] - 0s 6ms/step - loss: 1.0330 - accuracy: 0.6110 - val_loss: 0.9730 - val_accuracy: 0.6424
# Epoch 50/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.9391 - accuracy: 0.6467 - val_loss: 0.9452 - val_accuracy: 0.6354
# Epoch 51/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.9654 - accuracy: 0.6336 - val_loss: 1.1203 - val_accuracy: 0.5972
# Epoch 52/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.9741 - accuracy: 0.6422 - val_loss: 0.9396 - val_accuracy: 0.6632
# Epoch 53/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.9526 - accuracy: 0.6371 - val_loss: 0.8871 - val_accuracy: 0.6910
# Epoch 54/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.8710 - accuracy: 0.6869 - val_loss: 0.8130 - val_accuracy: 0.6944
# Epoch 55/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8338 - accuracy: 0.6885 - val_loss: 0.7563 - val_accuracy: 0.7153
# Epoch 56/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.8660 - accuracy: 0.6717 - val_loss: 0.9971 - val_accuracy: 0.6493
# Epoch 57/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.9307 - accuracy: 0.6668 - val_loss: 0.8406 - val_accuracy: 0.7049
# Epoch 58/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.8222 - accuracy: 0.6874 - val_loss: 0.8509 - val_accuracy: 0.6875
# Epoch 59/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.8872 - accuracy: 0.6717 - val_loss: 0.7195 - val_accuracy: 0.7326
# Epoch 60/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.7668 - accuracy: 0.7155 - val_loss: 0.7865 - val_accuracy: 0.7431
# Epoch 61/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.7900 - accuracy: 0.7003 - val_loss: 0.7896 - val_accuracy: 0.7153
# Epoch 62/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7294 - accuracy: 0.7252 - val_loss: 0.6256 - val_accuracy: 0.7639
# Epoch 63/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6414 - accuracy: 0.7511 - val_loss: 0.6020 - val_accuracy: 0.7778
# Epoch 64/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6817 - accuracy: 0.7436 - val_loss: 0.6362 - val_accuracy: 0.7778
# Epoch 65/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6977 - accuracy: 0.7442 - val_loss: 0.6889 - val_accuracy: 0.7465
# Epoch 66/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.7798 - accuracy: 0.7324 - val_loss: 0.6069 - val_accuracy: 0.7812
# Epoch 67/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.7558 - accuracy: 0.7381 - val_loss: 0.5712 - val_accuracy: 0.7917
# Epoch 68/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6357 - accuracy: 0.7654 - val_loss: 0.5605 - val_accuracy: 0.8021
# Epoch 69/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6358 - accuracy: 0.7801 - val_loss: 0.6497 - val_accuracy: 0.7847
# Epoch 70/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6231 - accuracy: 0.7742 - val_loss: 0.5254 - val_accuracy: 0.7951
# Epoch 71/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5182 - accuracy: 0.8005 - val_loss: 0.6458 - val_accuracy: 0.7674
# Epoch 72/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5672 - accuracy: 0.8040 - val_loss: 0.5534 - val_accuracy: 0.7986
# Epoch 73/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5429 - accuracy: 0.8143 - val_loss: 0.5951 - val_accuracy: 0.7917
# Epoch 74/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.5945 - accuracy: 0.7917 - val_loss: 0.4431 - val_accuracy: 0.8333
# Epoch 75/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.6688 - accuracy: 0.7660 - val_loss: 0.9520 - val_accuracy: 0.6840
# Epoch 76/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7744 - accuracy: 0.7287 - val_loss: 0.5866 - val_accuracy: 0.7847
# Epoch 77/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5286 - accuracy: 0.8119 - val_loss: 0.4596 - val_accuracy: 0.8438
# Epoch 78/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.7992 - accuracy: 0.7525 - val_loss: 0.6323 - val_accuracy: 0.7951
# Epoch 79/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.6138 - accuracy: 0.7917 - val_loss: 0.4682 - val_accuracy: 0.8125
# Epoch 80/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5409 - accuracy: 0.8226 - val_loss: 0.3906 - val_accuracy: 0.8472
# Epoch 81/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4087 - accuracy: 0.8646 - val_loss: 0.3420 - val_accuracy: 0.8715
# Epoch 82/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3800 - accuracy: 0.8775 - val_loss: 0.3398 - val_accuracy: 0.8715
# Epoch 83/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4174 - accuracy: 0.8317 - val_loss: 0.4967 - val_accuracy: 0.8438
# Epoch 84/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.5181 - accuracy: 0.8260 - val_loss: 0.4875 - val_accuracy: 0.8194
# Epoch 85/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4616 - accuracy: 0.8523 - val_loss: 0.4645 - val_accuracy: 0.8472
# Epoch 86/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.8588 - val_loss: 0.3411 - val_accuracy: 0.8819
# Epoch 87/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3802 - accuracy: 0.8536 - val_loss: 0.3463 - val_accuracy: 0.8750
# Epoch 88/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3760 - accuracy: 0.8700 - val_loss: 0.3491 - val_accuracy: 0.8819
# Epoch 89/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3990 - accuracy: 0.8644 - val_loss: 0.3226 - val_accuracy: 0.8785
# Epoch 90/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3614 - accuracy: 0.8814 - val_loss: 0.3897 - val_accuracy: 0.8715
# Epoch 91/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3962 - accuracy: 0.8779 - val_loss: 0.3366 - val_accuracy: 0.8924
# Epoch 92/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4234 - accuracy: 0.8770 - val_loss: 0.4266 - val_accuracy: 0.8438
# Epoch 93/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.4371 - accuracy: 0.8665 - val_loss: 0.2887 - val_accuracy: 0.8958
# Epoch 94/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3774 - accuracy: 0.8718 - val_loss: 0.3287 - val_accuracy: 0.8854
# Epoch 95/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3486 - accuracy: 0.8834 - val_loss: 0.2311 - val_accuracy: 0.9340
# Epoch 96/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2678 - accuracy: 0.9125 - val_loss: 0.2226 - val_accuracy: 0.9132
# Epoch 97/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2310 - accuracy: 0.9250 - val_loss: 0.2340 - val_accuracy: 0.9028
# Epoch 98/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2548 - accuracy: 0.9186 - val_loss: 0.1845 - val_accuracy: 0.9410
# Epoch 99/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2426 - accuracy: 0.9160 - val_loss: 0.2120 - val_accuracy: 0.9167
# Epoch 100/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2740 - accuracy: 0.9100 - val_loss: 0.3736 - val_accuracy: 0.8576
# Epoch 101/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3423 - accuracy: 0.8910 - val_loss: 0.2632 - val_accuracy: 0.9271
# Epoch 102/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3344 - accuracy: 0.8821 - val_loss: 0.3262 - val_accuracy: 0.8889
# Epoch 103/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2833 - accuracy: 0.9147 - val_loss: 0.2125 - val_accuracy: 0.9236
# Epoch 104/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2380 - accuracy: 0.9203 - val_loss: 0.2216 - val_accuracy: 0.9236
# Epoch 105/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2110 - accuracy: 0.9317 - val_loss: 0.2337 - val_accuracy: 0.8889
# Epoch 106/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2413 - accuracy: 0.9273 - val_loss: 0.1300 - val_accuracy: 0.9444
# Epoch 107/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2569 - accuracy: 0.9147 - val_loss: 0.2863 - val_accuracy: 0.9132
# Epoch 108/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.3613 - accuracy: 0.9028 - val_loss: 0.3937 - val_accuracy: 0.8681
# Epoch 109/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2697 - accuracy: 0.9207 - val_loss: 0.2238 - val_accuracy: 0.9306
# Epoch 110/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9357 - val_loss: 0.2056 - val_accuracy: 0.9340
# Epoch 111/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2050 - accuracy: 0.9396 - val_loss: 0.2144 - val_accuracy: 0.9167
# Epoch 112/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9347 - val_loss: 0.1085 - val_accuracy: 0.9618
# Epoch 113/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.1518 - accuracy: 0.9545 - val_loss: 0.1502 - val_accuracy: 0.9583
# Epoch 114/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1455 - accuracy: 0.9557 - val_loss: 0.1028 - val_accuracy: 0.9653
# Epoch 115/121
# 72/72 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9410 - val_loss: 0.2838 - val_accuracy: 0.9236
# Epoch 116/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.2728 - accuracy: 0.9296 - val_loss: 0.2643 - val_accuracy: 0.9167
# Epoch 117/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3813 - accuracy: 0.8871 - val_loss: 0.4859 - val_accuracy: 0.8785
# Epoch 118/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.4099 - accuracy: 0.8704 - val_loss: 0.3060 - val_accuracy: 0.8958
# Epoch 119/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.3914 - accuracy: 0.8905 - val_loss: 0.1771 - val_accuracy: 0.9479
# Epoch 120/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.1972 - accuracy: 0.9318 - val_loss: 0.1287 - val_accuracy: 0.9479
# Epoch 121/121
# 72/72 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.9445 - val_loss: 0.1687 - val_accuracy: 0.9549

# %%
### loss plots using LSTM model
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### accuracy plots using LSTM model
plt.clf()                                                

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'ro', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### evaluate using model A
model_A.evaluate(np.expand_dims(ravdess_speech_data_array[training_samples + validation_samples:], -1), labels_categorical[training_samples + validation_samples:])
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1405 - accuracy: 0.9479
# [0.1405143141746521, 0.9479166865348816]

# %%
emotions={1 : 'neutral', 2 : 'calm', 3 : 'happy', 4 : 'sad', 5 : 'angry', 6 : 'fearful', 7 : 'disgust', 8 : 'surprised'}
def predict(wav_filepath):
  test_point=extract_mfcc(wav_filepath)
  test_point=np.reshape(test_point,newshape=(1,40,1))
  predictions=model_A.predict(test_point)
  print(emotions[np.argmax(predictions[0])+1])

# %%
predict('/content/drive/MyDrive/Colab Notebooks/ravdess-emotional-speech-audio/Actor_02/03-01-01-01-01-01-02.wav')
# Out:
# neutral

# %%
predict('/content/drive/MyDrive/test.wav')
# Out:
# calm

# %%
predict('/content/drive/MyDrive/Colab Notebooks/ravdess-emotional-speech-audio/Actor_01/03-01-08-01-01-02-01.wav')
# Out:
# surprised

# %%
model_A.save('mymodel.h5')

# %%
modelc=tf.keras.models.load_model('mymodel.h5')

# %%
predict('/akhil.wav')
# Out:
# happy

# %%
predict('/vd.wav')
# Out:
# angry
